# %% [markdown]
# <a href="https://colab.research.google.com/github/Danial-Amiri/OpenCv-Tutorials/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-contrib-python

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


#loc=image path

loc="/content/drive/MyDrive/Python/OpenCv/opencv-course-master/Resources/Photos/lady.jpg"
img = cv.imread(loc)
cv2_imshow(img)


#convert to gray
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray)


haar_cascade=cv.CascadeClassifier('/content/haarcascade_frontalface_default.xml')
faces_rect=haar_cascade.detectMultiScale(gray, 1.1, 3)

print(f"Number of faces detected: {len(faces_rect)}")

for (x,y,w,h) in faces_rect:
  cv.rectangle(img,(x,y),(x+w,y+h),(0,255,0),thickness=2)

cv2_imshow(img)

cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=637x685>
# <PIL.Image.Image image mode=L size=637x685>
# Number of faces detected: 1
# <PIL.Image.Image image mode=RGB size=637x685>
# -1

# %%
# Out:
# --2023-07-29 13:31:02--  https://github.com/opencv/opencv/blob/0323761ea685e03b106bd7612a10756c7fbd6ef9/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2824255 (2.7M) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>]   2.69M  --.-KB/s    in 0.08s
#
# 2023-07-29 13:31:02 (33.5 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [2824255/2824255]
